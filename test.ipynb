# %%
import json
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

from load_glove import Embedding, Glove, LoadPretrainedGlove
from models import SkipGram, CBOW, NN

# %%
# LoadPretrainedGlove was implemented to load the pre-trained Glove embeddings
# the default was set to use the 100d embedding model, model has about 1.2m embeddings
# can pass in a filepath for other embedding dimensions to load other pre-trained embeddings
# Glove has 25d, 50d, 100d, and 200d online. Note that 200d takes a long time to load (27 billions * 200 total floats)
# LoadPretrainedGlove returns a Glove object
EMBEDDING_DIM = 100
glove_model = LoadPretrainedGlove() # use default 100d model

# %%
glove_model
# Out:
# <Glove_object num_tokens.1193517 vec_dim.100>

# %%
# test functionality of the model (can skip), so far I only implemented five methods
# get_vector will get the embeddings of a token (Glove made all tokens lower cases)
glove_model.get_vector('Michael')
# Out:
# 'Michael' not in the model

# %%
# test functionality of the model (can skip), so far I only implemented five methods
# similarity will retrieve the embeddings and compute the consine similarity between two given tokens
glove_model.similarity('excellent', 'great')
# Out:
# 0.7804909766934288

# %%
# test functionality of the model (can skip), so far I only implemented five methods
# most_similar can be used to map the word embedding back to the most similar word in the model using cosine
glove_model.most_similar('excellent')
# Out:
# [('fantastic', 0.7891919692639917),
#  ('great', 0.7804909766934288),
#  ('brilliant', 0.7707372695455804),
#  ('superb', 0.7450593638693023),
#  ('outstanding', 0.7220487414581103),
#  ('terrific', 0.7189632766496982),
#  ('unique', 0.713248325184925),
#  ('article', 0.7111885947728657),
#  ('very', 0.7083041440709903),
#  ('interesting', 0.7079968065670241)]

# %%
# test functionality of the model (can skip), so far I only implemented five methods
# similarity_embedding can be used to compute the similarity between two input embeddings
# it basically just compute the consine similarity between two vectors
glove_model.similarity_embedding([1, 0, 1], [1, 0, 1])
# Out:
# 0.9999999999999998

# %%
# test functionality of the model (can skip), so far I only implemented five methods
# most_similar_token find the most similar words with the input word embedding
# by default it returns top 10 most similar words and the similarity with the input embedding
# can change top_n to any number
glove_model.most_similar_token(glove_model.get_vector('excellent'))
# Out:
# [('fantastic', 0.7891919692639917),
#  ('great', 0.7804909766934288),
#  ('brilliant', 0.7707372695455804),
#  ('superb', 0.7450593638693023),
#  ('outstanding', 0.7220487414581103),
#  ('terrific', 0.7189632766496982),
#  ('unique', 0.713248325184925),
#  ('article', 0.7111885947728657),
#  ('very', 0.7083041440709903),
#  ('interesting', 0.7079968065670241)]

# %%
# load test set, here all data from original was used
# the original set has even more words that are not in the model -- a lot of them were misspelled

token_to_embedding_test = {}
not_pretrained = 0

with open('tokenized.spelling.txt', 'r', encoding='utf-8') as textfile:
    line = textfile.readline()
    while line:
        line = line.strip('\n')
        line = line.split()
        for token in line:
            # for each unique token appeared in the training data, get a pretrained embedding 
            token = token.lower() # since Glove only encoded lower case embeddings
            if token not in token_to_embedding_test.keys():
                pretrained = glove_model.get_vector(token)
                if pretrained == None:
                    # only get the unkonwn words and their dependencies
                    not_pretrained += 1
                token_to_embedding_test[token.lower()] = pretrained
        line = textfile.readline()
        
vocab_size = len(token_to_embedding_test)
print('{} unknown tokens that are not in the model'.format(not_pretrained))
print('{} sentences with unkonwn tokens loaded'.format(vocab_size))
# Out:
# 'forne' not in the model
# 'ennoying' not in the model
# 'sinccerly' not in the model
# 'pressume' not in the model
# 'fhing' not in the model
# 'sathurday' not in the model
# 'troubbles' not in the model
# 'programms' not in the model
# 'organying' not in the model
# 'concers' not in the model
# 'caracterize' not in the model
# 'reasonably-piced' not in the model
# 'accomodations' not in the model
# 'emprove' not in the model
# '-lrb-' not in the model
# '-rrb-' not in the model
# 'sandwich-man' not in the model
# 'well-orginised' not in the model
# 'wezy' not in the model
# 'apresented' not in the model
# 'stily' not in the model
# 'arsts' not in the model
# '21-22' not in the model
# 'reasonaly-priced' not in the model
# 'recommand' not in the model
# 'appliaces' not in the model
# 'whed' not in the model
# 'visitores' not in the model
# 'intrestng' not in the model
# 'promontion' not in the model
# 'languagers' not in the model
# '2' not in the model
# '2000' not in the model
# 'fashonable' not in the model
# 'mentionned' not in the model
# 'studenst' not in the model
# 'writeing' not in the model
# 'atracite' not in the model
# 'incomon' not in the model
# '?!' not in the model
# 'concerntration' not in the model
# 'opionions' not in the model
# 'calulate' not in the model
# 'weedend' not in the model
# 'ôdo' not in the model
# 'combinient' not in the model
# 'helpul' not in the model
# 'appreicate' not in the model
# 'interesed' not in the model
# 'groue' not in the model
# 'secoundly' not in the model
# 'coluor' not in the model
# 'paht' not in the model
# 'dungeen' not in the model
# 'disadvatage' not in the model
# 'conclusuon' not in the model
# 'stricht' not in the model
# 'beheviour' not in the model
# 'strickt' not in the model
# 'fesival' not in the model
# 'detailes' not in the model
# 'pursuading' not in the model
# 'unfortuneatly' not in the model
# 'organiced' not in the model
# '21' not in the model
# '22' not in the model
# 'concets' not in the model
# '18' not in the model
# 'carrear' not in the model
# 'foregive' not in the model
# 'schoes' not in the model
# 'kownlegth' not in the model
# '10' not in the model
# 'pocket-money' not in the model
# 'intesting' not in the model
# 'luxualy' not in the model
# 'salaly' not in the model
# 'congratualate' not in the model
# '11' not in the model
# 'festivel' not in the model
# 'vareiety' not in the model
# 'entrence' not in the model
# 'claryfy' not in the model
# 'portrate' not in the model
# 'contries' not in the model
# 'nationallites' not in the model
# 'teeenage' not in the model
# 'appoitments' not in the model
# 'exbitions' not in the model
# 'excenent' not in the model
# 'halled' not in the model
# 'wchool' not in the model
# 'diciplined' not in the model
# 'chuingham' not in the model
# 'commitent' not in the model
# '20.15' not in the model
# 'redicoulus' not in the model
# 'necessiraly' not in the model
# 'wersting' not in the model
# 'developes' not in the model
# 'impruvement' not in the model
# 'thrutly' not in the model
# 'smailing' not in the model
# '19.30' not in the model
# 'forthy' not in the model
# 'extrrmely' not in the model
# 'advertisiment' not in the model
# 'difents' not in the model
# 'publised' not in the model
# 'desagreable' not in the model
# 'unpleased' not in the model
# 'heaed' not in the model
# 'safty-money' not in the model
# 'schoked' not in the model
# 'mr/mss' not in the model
# '20:15' not in the model
# 'althoug' not in the model
# '19:30' not in the model
# 'techology' not in the model
# 'centure' not in the model
# 'coocking' not in the model
# 'advertistment' not in the model
# 'advertissement' not in the model
# 'gratfull' not in the model
# 'charakters' not in the model
# 'sourranding' not in the model
# 'advantatges' not in the model
# 'disadvantatges' not in the model
# 'anwered' not in the model
# 'apologaising' not in the model
# 'unavilable' not in the model
# 'adition' not in the model
# 'simplier' not in the model
# 'especialized' not in the model
# 'umpleasant' not in the model
# 'learm' not in the model
# 'embarased' not in the model
# 'secendly' not in the model
# 'beginig' not in the model
# 'deceperous' not in the model
# 'complaines' not in the model
# 'surranding' not in the model
# 'recompansate' not in the model
# 'healf' not in the model
# 'syntethic' not in the model
# 'fourty-five' not in the model
# 'camirez' not in the model
# 'compleints' not in the model
# '19.20' not in the model
# '40' not in the model
# '...' not in the model
# 'demostrated' not in the model
# 'complein' not in the model
# 'formaly' not in the model
# 'explein' not in the model
# 'phisically' not in the model
# '45' not in the model
# 'avaivable' not in the model
# 'opertunity' not in the model
# 'disatvantage' not in the model
# 'unpleasent' not in the model
# 'oppened' not in the model
# 'discouts' not in the model
# '20.00' not in the model
# 'resposbillity' not in the model
# 'complane' not in the model
# 'reastaurant' not in the model
# 'whatoever' not in the model
# 'minuits' not in the model
# 'detictive' not in the model
# 'naraitors' not in the model
# 'hepful' not in the model
# 'boried' not in the model
# 'argeuments' not in the model
# 'ambisious' not in the model
# 'grouded' not in the model
# 'farrster' not in the model
# 'characther' not in the model
# 'absoletuly' not in the model
# 'deleyed' not in the model
# 'unfortunely' not in the model
# 'franckly' not in the model
# 'uncamfortable' not in the model
# 'recentely' not in the model
# 'interrested' not in the model
# '20' not in the model
# 'therapi' not in the model
# 'techonology' not in the model
# 'reguard' not in the model
# 'secundary' not in the model
# 'ingenors' not in the model
# 'disapponted' not in the model
# 'teachnology' not in the model
# 'profeccion' not in the model
# 'meditarenian' not in the model
# 'coleagues' not in the model
# 'dissaproved' not in the model
# 'theathre' not in the model
# 'sir/madame' not in the model
# 'sencerely' not in the model
# 'schoole' not in the model
# 'puple' not in the model
# 'prooth' not in the model
# 'acquintance' not in the model
# 'unpredicatable' not in the model
# 'suffured' not in the model
# 'mananger' not in the model
# 'unfortunatety' not in the model
# 'garenteed' not in the model
# 'equippments' not in the model
# 'brocher' not in the model
# 'comletely' not in the model
# 'informatonal' not in the model
# 'resaurant' not in the model
# 'telefonnumber' not in the model
# 'despleased' not in the model
# 'anouced' not in the model
# 'anchient' not in the model
# 'farmily' not in the model
# 'sciencetist' not in the model
# 'perdict' not in the model
# 'perpare' not in the model
# 'diseasters' not in the model
# 'amaisingly' not in the model
# 'umpleasent' not in the model
# '8:15' not in the model
# 'diffarent' not in the model
# '14.30' not in the model
# '160' not in the model
# 'finissed' not in the model
# '00.15' not in the model
# '00.00' not in the model
# 'complaine' not in the model
# 'he/she' not in the model
# 'stricher' not in the model
# '3' not in the model
# 'sientific' not in the model
# 'computeres' not in the model
# 'almodar' not in the model
# 'unaspected' not in the model
# 'exagerate' not in the model
# 'supposted' not in the model
# 'sinecerely' not in the model
# 'fantascientific' not in the model
# 'faithully' not in the model
# 'faitully' not in the model
# 'leafet' not in the model
# 'energry' not in the model
# 'modles' not in the model
# 'besorrted' not in the model
# 'entertament' not in the model
# 'fathermore' not in the model
# 'writed' not in the model
# 'becomed' not in the model
# 'permormed' not in the model
# 'suppoused' not in the model
# 'ennoyed' not in the model
# 'accutely' not in the model
# '16' not in the model
# 'hundsom' not in the model
# 'volontary' not in the model
# 'hypocrital' not in the model
# 'constums' not in the model
# 'rejective' not in the model
# 'honestity' not in the model
# 'roddos' not in the model
# 'stablishment' not in the model
# 'devellopment' not in the model
# 'undstand' not in the model
# '100' not in the model
# 'incredably' not in the model
# 'sun-glasses' not in the model
# 'main-actor' not in the model
# '21:00' not in the model
# 'surburb' not in the model
# 'temptention' not in the model
# 'horiday' not in the model
# 'whlile' not in the model
# 'helful' not in the model
# '19:15' not in the model
# 'immidiately' not in the model
# 'repeard' not in the model
# 'ievel' not in the model
# 'dissapointted' not in the model
# 'unusuall' not in the model
# 'relatinships' not in the model
# 'evoluated' not in the model
# 'advicing' not in the model
# 'maschines' not in the model
# 'washing-up' not in the model
# 'surprizingly' not in the model
# 'unsuccesfull' not in the model
# '86' not in the model
# 'overherd' not in the model
# 'sincearly' not in the model
# 'sacondly' not in the model
# 'climed' not in the model
# 'councience' not in the model
# 'divorsed' not in the model
# '25' not in the model
# 'desagreeded' not in the model
# 'pubblic' not in the model
# 'informated' not in the model
# 'theatrer' not in the model
# '7' not in the model
# 'free-time' not in the model
# 'tecnologies' not in the model
# 'restraurants' not in the model
# 'diffences' not in the model
# 'availlable' not in the model
# 'disappointement' not in the model
# 'affending' not in the model
# 'competers' not in the model
# 'hundrets' not in the model
# 'prograns' not in the model
# 'reciently' not in the model
# 'sumarize' not in the model
# 'grownded' not in the model
# 'biscount' not in the model
# 'advertiment' not in the model
# 'proplems' not in the model
# 'efection' not in the model
# 'cetury' not in the model
# 'thechnology' not in the model
# 'environement' not in the model
# 'mobile-phone' not in the model
# 'data-bank' not in the model
# 'becaused' not in the model
# 'half-pass' not in the model
# 'threatre' not in the model
# 'differend' not in the model
# 'senciarly' not in the model
# 'pobular' not in the model
# 'catestrophee' not in the model
# 'sourrended' not in the model
# 'prepeared' not in the model
# 'faightfully' not in the model
# 'sciencist' not in the model
# 'neccesity' not in the model
# 'polyseer' not in the model
# 'plessure' not in the model
# 'becauses' not in the model
# 'inovations' not in the model
# 'practicate' not in the model
# 'hollydays' not in the model
# 'groseries' not in the model
# 'surpprising' not in the model
# 'studiant' not in the model
# 'centery' not in the model
# 'farbics' not in the model
# 'farbic' not in the model
# 'minitues' not in the model
# 'fourtunately' not in the model
# 'reliased' not in the model
# 'entred' not in the model
# 'ahsma' not in the model
# '17th' not in the model
# '23th' not in the model
# 'surrprised' not in the model
# '730' not in the model
# '815' not in the model
# 'thired' not in the model
# 'afternones' not in the model
# 'plouge' not in the model
# 'disappinted' not in the model
# 'brochar' not in the model
# 'brochour' not in the model
# 'serets' not in the model
# 'splited' not in the model
# 'realio-on' not in the model
# 'evertauly' not in the model
# '7:00' not in the model
# '7:30' not in the model
# 'comonly' not in the model
# 'dangarous' not in the model
# 'addvertisement' not in the model
# 'inocently' not in the model
# 'ect.' not in the model
# 'oppotunity' not in the model
# '30' not in the model
# 'defenately' not in the model
# 'afected' not in the model
# 'dictionnary' not in the model
# 'symplifying' not in the model
# 'developpment' not in the model
# 'dissision' not in the model
# 'posipole' not in the model
# 'refussed' not in the model
# 'pregned' not in the model
# 'confesed' not in the model
# 'disappoiting' not in the model
# 'itselfes' not in the model
# 'faivourite' not in the model
# 'apineon' not in the model
# 'niceer' not in the model
# 'evolutive' not in the model
# 'embarassd' not in the model
# 'developped' not in the model
# 'acodimy' not in the model
# 'technologycal' not in the model
# 'paiment' not in the model
# 'techological' not in the model
# 'unluckly' not in the model
# '5' not in the model
# 'recommened' not in the model
# 'scencial' not in the model
# 'supprsed' not in the model
# 'weaping' not in the model
# 'sarted' not in the model
# 'comfortbly' not in the model
# 'nessesery' not in the model
# 'exaiting' not in the model
# '!!!' not in the model
# 'enyway' not in the model
# 'evining' not in the model
# 'mempers' not in the model
# 'discouns' not in the model
# 'reastaure' not in the model
# 'adverstisement' not in the model
# 'requere' not in the model
# 'telefaxes' not in the model
# 'mashiens' not in the model
# 'telephon' not in the model
# 'cassually' not in the model
# 'begginer' not in the model
# 'posibilities' not in the model
# 'apologyse' not in the model
# 'complate' not in the model
# 'coloures' not in the model
# '1900' not in the model
# 'synethetic' not in the model
# 'scientis' not in the model
# 'acsident' not in the model
# 'waitted' not in the model
# 'fourthey' not in the model
# 'unfortunatelly' not in the model
# 'abbsend' not in the model
# 'thetre' not in the model
# 'sinceraly' not in the model
# 'instractur' not in the model
# 'lauthing' not in the model
# 'appologized' not in the model
# 'porpouse' not in the model
# 'diccounts' not in the model
# '20:75' not in the model
# 'understent' not in the model
# 'pregnency' not in the model
# 'expacted' not in the model
# 'everning' not in the model
# 'recoment' not in the model
# 'sensirly' not in the model
# 'physcological' not in the model
# 'accitend' not in the model
# 'revilied' not in the model
# 'compures' not in the model
# 'secontly' not in the model
# 'opportunaty' not in the model
# 'secrects' not in the model
# 'desappointing' not in the model
# 'organitzation' not in the model
# 'imformation' not in the model
# 'ticets' not in the model
# '15th' not in the model
# 'stearing' not in the model
# '11:00' not in the model
# 'demostration' not in the model
# 'lyter' not in the model
# 'imagetly' not in the model
# 'technolgy' not in the model
# 'computor' not in the model
# 'swiching' not in the model
# 'subjets' not in the model
# '50' not in the model
# 'nuclears' not in the model
# 'misarable' not in the model
# 'comodity' not in the model
# 'discountable' not in the model
# '20th' not in the model
# 'indespensible' not in the model
# '16th' not in the model
# 'knowbody' not in the model
# 'wispering' not in the model
# 'restaurand' not in the model
# 'fainthfully' not in the model
# 'nessary' not in the model
# 'adimnistration' not in the model
# 'pontuality' not in the model
# '19:00' not in the model
# 'famouis' not in the model
# 'desorganized' not in the model
# 'angree' not in the model
# 'ofered' not in the model
# 'swimingpool' not in the model
# 'expent' not in the model
# 'sudently' not in the model
# 'orginize' not in the model
# 'dyscoteque' not in the model
# 'dyscotheque' not in the model
# 'enthousiasm' not in the model
# 'eegenering' not in the model
# 'explictions' not in the model
# '!!' not in the model
# 'minuties' not in the model
# 'encourageing' not in the model
# 'big-mouth' not in the model
# 'ploblem' not in the model
# 'simpliest' not in the model
# 'reserches' not in the model
# 'sanday' not in the model
# 'rensposible' not in the model
# 'explainations' not in the model
# 'apears' not in the model
# 'overspended' not in the model
# 'substitudes' not in the model
# 'tairs' not in the model
# 'defineteley' not in the model
# 'surprisinggly' not in the model
# 'proformed' not in the model
# 'aventage' not in the model
# 'disaventage' not in the model
# 'effecient' not in the model
# 'theart' not in the model
# 'deciced' not in the model
# 'devorce' not in the model
# 'wrotte' not in the model
# 'dekoreting' not in the model
# 'wrott' not in the model
# 'subjekt' not in the model
# 'institue' not in the model
# 'mashines' not in the model
# 'cumputer' not in the model
# 'mentenance' not in the model
# 'addittion' not in the model
# 'controversary' not in the model
# 'opinnion' not in the model
# 'adventage' not in the model
# 'innacuracies' not in the model
# 'memoriable' not in the model
# 'eletricity' not in the model
# 'imagene' not in the model
# 'avarage' not in the model
# 'behaveare' not in the model
# 'experement' not in the model
# 'experements' not in the model
# 'requiered' not in the model
# 'ashmatic' not in the model
# 'appreciatte' not in the model
# 'oportunitty' not in the model
# 'forwart' not in the model
# 'responsble' not in the model
# 'greating' not in the model
# 'accound' not in the model
# 'mechine' not in the model
# 'afteroon' not in the model
# 'preseant' not in the model
# 'pickpokets' not in the model
# '13th' not in the model
# 'perticular' not in the model
# 'gothave' not in the model
# 'accostomed' not in the model
# 'helpying' not in the model
# 'thusands' not in the model
# 'clotches' not in the model
# 'reciving' not in the model
# 'receised' not in the model
# 'thanck' not in the model
# 'faitfull' not in the model
# '6:30' not in the model
# '8:30' not in the model
# 'enjoining' not in the model
# 'especifics' not in the model
# 'privelage' not in the model
# 'refiguration' not in the model
# 'recommondations' not in the model
# 'antropological' not in the model
# 'psicological' not in the model
# 'sortted' not in the model
# 'studant' not in the model
# 'acomodations' not in the model
# 'absolutaly' not in the model
# 'fasinating' not in the model
# 'scenaries' not in the model
# 'conludes' not in the model
# 'mantein' not in the model
# 'prepairing' not in the model
# 'aproppiates' not in the model
# 'paragraps' not in the model
# 'suppermarket' not in the model
# 'convenien' not in the model
# 'inbelivable' not in the model
# '125' not in the model
# 'repply' not in the model
# 'experiece' not in the model
# 'inverviews' not in the model
# 'satisfation' not in the model
# 'esepically' not in the model
# 'retailors' not in the model
# 'arrenge' not in the model
# 'stooud' not in the model
# 'prepear' not in the model
# 'enjeyable' not in the model
# 'recyling' not in the model
# 'amuzing' not in the model
# 'injoyed' not in the model
# 'acurately' not in the model
# 'whather' not in the model
# 'shop-cravers' not in the model
# 'croude' not in the model
# 'unplesent' not in the model
# 'teachear' not in the model
# 'croara' not in the model
# 'aproximately' not in the model
# 'realizeable' not in the model
# 'serpride' not in the model
# 'goging' not in the model
# 'interessting' not in the model
# 'enigy' not in the model
# 'alfrell' not in the model
# 'smely' not in the model
# '4:30' not in the model
# 'tent.' not in the model
# 'corfotabel' not in the model
# 'instand' not in the model
# 'expences' not in the model
# 'apreicate' not in the model
# 'acxepted' not in the model
# 'assiment' not in the model
# 'audients' not in the model
# 'veriety' not in the model
# 'qustions' not in the model
# 'privete' not in the model
# 'super-markets' not in the model
# 'conveniance' not in the model
# 'equitment' not in the model
# 'engieners' not in the model
# 'teeth-bruches' not in the model
# 'fifteeth' not in the model
# 'interessted' not in the model
# 'houndreds' not in the model
# 'coblights' not in the model
# 'activitie' not in the model
# 'guittars' not in the model
# 'inclued' not in the model
# 'opininion' not in the model
# 'spaise' not in the model
# 'harrodss' not in the model
# 'summerize' not in the model
# 'conclution' not in the model
# 'disavantages' not in the model
# 'sevral' not in the model
# 'queus' not in the model
# 'custumer' not in the model
# 'partecipation' not in the model
# 'techinique' not in the model
# 'deffect' not in the model
# 'water-polo' not in the model
# 'specealized' not in the model
# 'mecanics' not in the model
# 'extrict' not in the model
# 'nutchel' not in the model
# 'agresive' not in the model
# 'riched' not in the model
# 'appropiet' not in the model
# 'repeared' not in the model
# 'techical' not in the model
# 'wodden' not in the model
# 'extressing' not in the model
# 'othrewise' not in the model
# 'cuantities' not in the model
# 'encrease' not in the model
# 'prapare' not in the model
# 'proude' not in the model
# 'priec' not in the model
# 'plesant' not in the model
# 'suppling' not in the model
# 'holp' not in the model
# 'enjoed' not in the model
# 'unconected' not in the model
# 'addmit' not in the model
# 'flaing' not in the model
# 'baddly' not in the model
# 'nuture' not in the model
# 'sclumbling' not in the model
# 'auguest' not in the model
# 'embaracing' not in the model
# 'infrom' not in the model
# 'atmosephere' not in the model
# 'intermidiate' not in the model
# 'accomodated' not in the model
# 'sailling' not in the model
# 'sea-sports' not in the model
# 'valunteer' not in the model
# 'adversitement' not in the model
# 'forigen' not in the model
# 'greateful' not in the model
# 'nigthmare' not in the model
# 'ameaising' not in the model
# 'anfair' not in the model
# 'addecuate' not in the model
# 'exhiting' not in the model
# 'fantactic' not in the model
# 'recemmend' not in the model
# 'spezialised' not in the model
# 'intertainments' not in the model
# 'attituds' not in the model
# 'attaked' not in the model
# 'questionnair' not in the model
# 'nessesserly' not in the model
# 'absolutlly' not in the model
# 'tooletes' not in the model
# 'preferances' not in the model
# 'scinerly' not in the model
# 'enougher' not in the model
# 'lookind' not in the model
# 'gubin' not in the model
# 'exsample' not in the model
# 'resently' not in the model
# 'oppertunate' not in the model
# 'recommond' not in the model
# '1st' not in the model
# 'approxiametely' not in the model
# 'fordward' not in the model
# 'straingth' not in the model
# 'pleaseant' not in the model
# '15' not in the model
# 'culculate' not in the model
# 'possebility' not in the model
# 'conections' not in the model
# 'ivited' not in the model
# 'inventation' not in the model
# 'grebenchekoff' not in the model
# 'succsessful' not in the model
# 'septenber' not in the model
# 'acctivities' not in the model
# 'discribing' not in the model
# 'avaliabel' not in the model
# 'exating' not in the model
# '30th' not in the model
# 'practis' not in the model
# 'oppurnity' not in the model
# 'aguest' not in the model
# 'stationeries' not in the model
# 'jakect' not in the model
# 'enjyoi' not in the model
# 'charachters' not in the model
# 'charachter' not in the model
# 'houskeeper' not in the model
# 'writeng' not in the model
# 'classicial' not in the model
# 'questionarie' not in the model
# 'californiai' not in the model
# 'unusal' not in the model
# 'appartheid' not in the model
# 'prond' not in the model
# 'ikurapiura' not in the model
# 'guiters' not in the model
# 'mace-up' not in the model
# 'scenography' not in the model
# 'sizors' not in the model
# 'accomotation' not in the model
# 'somitimes' not in the model
# 'jewells' not in the model
# 'inttetion' not in the model
# 'exlaimed' not in the model
# 'remainds' not in the model
# 'athmospher' not in the model
# 'technich' not in the model
# 'conecting' not in the model
# 'spekers' not in the model
# 'departnent' not in the model
# 'electronical' not in the model
# 'concernt' not in the model
# 'aougust' not in the model
# 'necessery' not in the model
# 'sinicrely' not in the model
# 'acommodation' not in the model
# 'templary' not in the model
# 'equepument' not in the model
# 'compricate' not in the model
# 'cranberies' not in the model
# 'guitarrist' not in the model
# 'bascketball' not in the model
# 'enjouable' not in the model
# 'factorors' not in the model
# 'expencive' not in the model
# 'diffence' not in the model
# 'rachiat' not in the model
# 'climp' not in the model
# 'concentrat' not in the model
# 'imortant' not in the model
# 'ansering' not in the model
# 'nesseceraly' not in the model
# 'fashing' not in the model
# 'scubar' not in the model
# 'floting' not in the model
# 'favarite' not in the model
# 'rutines' not in the model
# 'behaviers' not in the model
# 'supecial' not in the model
# 'ceremonys' not in the model
# 'sound-check' not in the model
# 'abosolutly' not in the model
# 'espacially' not in the model
# 'appropreaite' not in the model
# 'photograher' not in the model
# 'cathegory' not in the model
# 'carbins' not in the model
# 'excute' not in the model
# 'receved' not in the model
# 'meong-dong' not in the model
# 'uderground' not in the model
# 'enjobleable' not in the model
# 'intitled' not in the model
# 'appriciation' not in the model
# 'assisstants' not in the model
# 'entring' not in the model
# 'voluntier' not in the model
# 'atmospher' not in the model
# 'military-service' not in the model
# 'spessial' not in the model
# 'speccial' not in the model
# 'incovenients' not in the model
# 'convinent' not in the model
# 'wonner' not in the model
# 'aspecially' not in the model
# 'hipermarkets' not in the model
# 'durind' not in the model
# 'opitions' not in the model
# 'praticing' not in the model
# 'rotine' not in the model
# 'enjoyables' not in the model
# 'majorite' not in the model
# 'deaps' not in the model
# '1998' not in the model
# 'depents' not in the model
# 'dicided' not in the model
# 'didwas' not in the model
# 'thousends' not in the model
# 'courtines' not in the model
# 'achived' not in the model
# 'robotich' not in the model
# 'mecanic' not in the model
# 'ingenier' not in the model
# 'defnitely' not in the model
# 'adquiring' not in the model
# '6:00' not in the model
# '2:00' not in the model
# '12:00' not in the model
# 'incredibale' not in the model
# 'greatefully' not in the model
# 'murther' not in the model
# 'fotographs' not in the model
# 'autographied' not in the model
# 'comenicate' not in the model
# 'aceptance' not in the model
# '12' not in the model
# 'alwalys' not in the model
# 'phtograghy' not in the model
# 'comportable' not in the model
# 'currancies' not in the model
# 'accesoires' not in the model
# 'novadays' not in the model
# 'hich-hicking' not in the model
# 'puzzeled' not in the model
# 'elucidaded' not in the model
# 'succesed' not in the model
# 'croweded' not in the model
# 'counscious' not in the model
# 'michrophones' not in the model
# 'enjouble' not in the model
# 'morover' not in the model
# 'backace' not in the model
# 'fourious' not in the model
# 'hostessess' not in the model
# 'prepered' not in the model
# 'pot-au-fleurs' not in the model
# 'unspected' not in the model
# 'repplies' not in the model
# 'atmosphier' not in the model
# 'clasifay' not in the model
# 'liabrary' not in the model
# 'sourvive' not in the model
# 'pertners' not in the model
# 'extravacant' not in the model
# 'orginazer' not in the model
# 'exsiting' not in the model
# 'empressted' not in the model
# 'fainally' not in the model
# 'usedful' not in the model
# 'steat' not in the model
# 'accommadated' not in the model
# 'intered' not in the model
# '7th' not in the model
# 'ecited' not in the model
# 'reguest' not in the model
# 'sincirely' not in the model
# 'houndred' not in the model
# 'foreginers' not in the model
# 'ricently' not in the model
# 'maners' not in the model
# 'summerise' not in the model
# 'weakdays' not in the model
# 'evoques' not in the model
# 'receave' not in the model
# 'teatchers' not in the model
# 'teatcher' not in the model
# '13rd' not in the model
# 'foreing' not in the model
# 'teachears' not in the model
# 'crouded' not in the model
# 'ejoyable' not in the model
# 'tramits' not in the model
# 'accomodtion' not in the model
# 'lukiest' not in the model
# 'sigers' not in the model
# 'satisfing' not in the model
# 'throughlly' not in the model
# 'sincierly' not in the model
# 'tersty' not in the model
# 'accommnodation' not in the model
# 'safier' not in the model
# 'spleeping' not in the model
# 'combins' not in the model
# 'acommodations' not in the model
# 'campping' not in the model
# 'analaising' not in the model
# 'avrege' not in the model
# 'definetelly' not in the model
# 'tecnical' not in the model
# 'foucosed' not in the model
# 'culturs' not in the model
# 'beginers' not in the model
# 'pratise' not in the model
# 'crambled' not in the model
# 'espectators' not in the model
# 'moroever' not in the model
# 'handduring' not in the model
# 'mattres' not in the model
# 'seill' not in the model
# 'fortunetly' not in the model
# 'accomodationed' not in the model
# 'thirsthly' not in the model
# 'wotch' not in the model
# 'aditional' not in the model
# 'enthusiatic' not in the model
# 'receveid' not in the model
# 'permition' not in the model
# 'articals' not in the model
# 'accodance' not in the model
# 'sincerately' not in the model
# 'wistling' not in the model
# 'favoorate' not in the model
# 'monstruous' not in the model
# 'ingredians' not in the model
# 'misteries' not in the model
# 'itselves' not in the model
# 'wethear' not in the model
# 'particurely' not in the model
# 'chedicard' not in the model
# 'authographs' not in the model
# '250' not in the model
# 'promosion' not in the model
# 'pop-concert' not in the model
# 'responsabilities' not in the model
# 'brönte' not in the model
# 'afimation' not in the model
# 'activitily' not in the model
# 'sceanary' not in the model
# 'eshausted' not in the model
# 'costemers' not in the model
# 'nowday' not in the model
# 'shopcholic' not in the model
# 'spokeperson' not in the model
# 'newspepper' not in the model
# 'chilldren' not in the model
# 'usauly' not in the model
# 'preper' not in the model
# 'clasrooms' not in the model
# '4.000' not in the model
# 'spactetors' not in the model
# 'statemant' not in the model
# 'souveniere' not in the model
# 'stundents' not in the model
# 'loocked' not in the model
# 'bugglar' not in the model
# 'enderstand' not in the model
# 'compehension' not in the model
# 'whateaver' not in the model
# 'excuiting' not in the model
# '14' not in the model
# '14th' not in the model
# 'fellowing' not in the model
# 'exhibiots' not in the model
# 'eveninng' not in the model
# 'respectabled' not in the model
# 'atraction' not in the model
# 'extremaly' not in the model
# 'wisiting' not in the model
# 'nowedays' not in the model
# 'leissure' not in the model
# 'sincererly' not in the model
# 'orginesed' not in the model
# '12th' not in the model
# 'favoreable' not in the model
# 'discorve' not in the model
# 'pleisure' not in the model
# 'lovestories' not in the model
# 'recone' not in the model
# 'litteracy' not in the model
# '10.00' not in the model
# '19.00' not in the model
# 'bycyle' not in the model
# 'deppresion' not in the model
# 'cryptographic' not in the model
# 'algoritms' not in the model
# 'oppurtinatey' not in the model
# 'tv-set' not in the model
# 'ciling' not in the model
# 'authopraps' not in the model
# 'fained' not in the model
# 'meaby' not in the model
# 'impersonally' not in the model
# 'atmosfear' not in the model
# 'interrests' not in the model
# 'kexhibition' not in the model
# '10:00' not in the model
# 'incovenience' not in the model
# 'jumed' not in the model
# 'priciples' not in the model
# 'studends' not in the model
# 'instide' not in the model
# 'exampel' not in the model
# 'coincidentely' not in the model
# 'bravure' not in the model
# 'recollet' not in the model
# 'everying' not in the model
# 'utilitles' not in the model
# 'promissing' not in the model
# 'clowds' not in the model
# 'acient' not in the model
# 'jouralists' not in the model
# 'enourmous' not in the model
# 'organasation' not in the model
# 'dangeres' not in the model
# 'futere' not in the model
# 'sportwear' not in the model
# 'journalit' not in the model
# 'romours' not in the model
# 'imagintive' not in the model
# 'inconveint' not in the model
# 'scilence' not in the model
# 'full-bloomed' not in the model
# 'blossam' not in the model
# 'viseted' not in the model
# 'attroction' not in the model
# 'happeness' not in the model
# 'linched' not in the model
# 'prisonner' not in the model
# 'garding' not in the model
# 'desagree' not in the model
# 'unexpectable' not in the model
# 'desings' not in the model
# 'entrace' not in the model
# 'hesistate' not in the model
# 'laisure' not in the model
# 'demonstation' not in the model
# 'paparach' not in the model
# 'admittion' not in the model
# 'detile' not in the model
# 'buillding' not in the model
# 'experied' not in the model
# 'comfortible' not in the model
# '10.00-19.00' not in the model
# 'rapdily' not in the model
# 'becaues' not in the model
# 'exmaple' not in the model
# 'prery' not in the model
# 'reprecentation' not in the model
# 'courner' not in the model
# 'advetisement' not in the model
# 'hairstyl' not in the model
# 'seeside' not in the model
# 'appritiate' not in the model
# 'leisur' not in the model
# 'fasions' not in the model
# 'intrsted' not in the model
# 'furiture' not in the model
# 'importand' not in the model
# 'teenaties' not in the model
# 'pshycological' not in the model
# 'sociaty' not in the model
# 'secratary' not in the model
# 'divertion' not in the model
# 'carleon' not in the model
# 'indivisuals' not in the model
# 'lugages' not in the model
# 'five-minutes' not in the model
# 'electicity' not in the model
# 'well-situated' not in the model
# 'plesuare' not in the model
# 'unfornutely' not in the model
# 'motorization' not in the model
# 'inconvinient' not in the model
# 'nyremberg' not in the model
# 'sutiation' not in the model
# 'sincerley' not in the model
# '9:00' not in the model
# 'museam' not in the model
# 'arboriginal' not in the model
# '1999' not in the model
# 'musseum' not in the model
# 'hernon' not in the model
# 'end-of-conference' not in the model
# 'cattering' not in the model
# 'souroundings' not in the model
# 'forniture' not in the model
# 'comfortables' not in the model
# '234' not in the model
# 'situatet' not in the model
# 'st.-petersburg' not in the model
# 'famious' not in the model
# 'marvellouse' not in the model
# 'architerture' not in the model
# 'xviiith' not in the model
# 'shutel' not in the model
# 'cotages' not in the model
# 'romanics' not in the model
# 'acomodation' not in the model
# 'resart' not in the model
# 'tecnonology' not in the model
# 'arquitector' not in the model
# 'lugguage' not in the model
# '1948' not in the model
# 'demaged' not in the model
# 'footh' not in the model
# 'eye-max' not in the model
# 'garelty' not in the model
# 'locted' not in the model
# 'historcall' not in the model
# 'picthurs' not in the model
# 'reseption' not in the model
# 'wellkown' not in the model
# 'expectetions' not in the model
# 'hystorical' not in the model
# 'now-a-day' not in the model
# 'washmachines' not in the model
# 'tradional' not in the model
# 'inculds' not in the model
# 'labrary' not in the model
# 'picadelly' not in the model
# 'vistit' not in the model
# 'city-centre' not in the model
# 'surposed' not in the model
# 'hestitate' not in the model
# 'estart' not in the model
# 'procesing' not in the model
# 'perfored' not in the model
# 'smol' not in the model
# 'aeche' not in the model
# 'codig' not in the model
# 'alchocholich' not in the model
# 'aeroplans' not in the model
# 'convenent' not in the model
# 'nember' not in the model
# '101' not in the model
# 'televesion' not in the model
# 'sport-musseum' not in the model
# 'reconvillier-park' not in the model
# 'recomnendations' not in the model
# 'seventienth-century' not in the model
# 'professers' not in the model
# 'semi-professers' not in the model
# 'acquerium' not in the model
# 'participacients' not in the model
# 'occationaly' not in the model
# 'cassets' not in the model
# 'cathedrall' not in the model
# 'undergroud' not in the model
# 'buhha' not in the model
# 'luxuery' not in the model
# 'motobikes' not in the model
# 'kei-shek' not in the model
# 'momerial' not in the model
# 'rememberence' not in the model
# 'gallaries' not in the model
# 'mininute' not in the model
# 'thingh' not in the model
# 'contanct' not in the model
# 'suitbility' not in the model
# 'centeral' not in the model
# 'accomadation' not in the model
# 'clouths' not in the model
# 'cannals' not in the model
# 'shuttel-bus' not in the model
# 'conference-center' not in the model
# 'city-tour' not in the model
# 'regred' not in the model
# 'phisical' not in the model
# 'conferents' not in the model
# 'definely' not in the model
# 'creeting' not in the model
# 'enviromment' not in the model
# 'commensing' not in the model
# '31st' not in the model
# '2001' not in the model
# '10.00-15.00' not in the model
# 'city-walk' not in the model
# 'exibitions' not in the model
# 'ceilar' not in the model
# 'availiable' not in the model
# 'advanturous' not in the model
# 'recommanded' not in the model
# 1212 unknown tokens that are not in the model
# 5127 sentences with unkonwn tokens loaded

# %%
# making test input
TEST_SIZE = 200
dependency_listing_test = []
max_length = 15
not_selected = 0

def TokensToEmbeddings(token_list):
    output_list = []
    for token in token_list:
        try:
            embedding = glove_model.get_vector(token)
            if embedding == None:
                embedding = [0 for i in range(EMBEDDING_DIM)]
        except KeyError:
            embedding = [0 for i in range(EMBEDDING_DIM)]
        output_list.extend(embedding)
    return output_list

def TokenToEmbedding(token, token_to_embedding):
    try:
        embedding = token_to_embedding[token]
    except KeyError:
        embedding = None
    return embedding

with open('dependencies.spelling.txt', 'r', encoding='utf-8') as textfile:
    metadata = json.load(textfile)
    for sentence in metadata:
        sentence_dependencies = {}
        for dep_relation in sentence:
            if dep_relation['dep'] == 'ROOT':
                continue # skip the root token as it doesn't have any dependency
            # word to predict is the governor, add all dependencies into the list of governor
            governor = dep_relation['governorGloss'].lower()
            dependent = dep_relation['dependentGloss'].lower()
            if governor not in sentence_dependencies.keys():
                sentence_dependencies[governor] = []
            sentence_dependencies[governor].append(dependent)
        for key, value in sentence_dependencies.items():
            if len(value) > 15:
                not_selected += 1
                continue
            dependency_listing_test.append([key, value])

print('{} / {} words having more than 15 dependencies not selected'.format(not_selected, len(dependency_listing_test) + not_selected))
# Out:
# 11 / 16112 words having more than 15 dependencies not selected

# %%
# get the unknown words to be label and its dependencies to be input
# test only 200 testing samples, as the computational cost for mapping the unknown word embedding to a known words is huge
# for each predicted word embedding, it has to compute the cosine similarity of that embedding with all 1.2M embeddings
# in the oroginal model then will find the most similar top n words to be the most similar known words

test_input = [[0, 0, 0] for i in range(TEST_SIZE)]
counter = 0

for (target, data) in dependency_listing_test:
    label = TokenToEmbedding(target, token_to_embedding_test)
    if label == None:
        counter += 1
        test_input[counter - 1][1] = torch.zeros(EMBEDDING_DIM)
        test_input[counter - 1][2] = target

        formatted_input = []
        embeddings = TokensToEmbeddings(data)
        formatted_input.extend(embeddings)
        if len(data) < max_length:
            # need padding if there are not enough dependencies
            padding_length = (max_length - len(data)) * EMBEDDING_DIM
            formatted_input.extend([0 for i in range(padding_length)])
        test_input[counter - 1][0] = torch.FloatTensor(formatted_input)
    if counter == TEST_SIZE:
        break
# Out:
# 'apresented' not in the model
# '21' not in the model
# '22' not in the model
# '22' not in the model
# 'forthy' not in the model
# 'disadvantatges' not in the model
# '45' not in the model
# '20:15' not in the model
# '...' not in the model
# 'sciencetist' not in the model
# 'diseasters' not in the model
# '19:30' not in the model
# '00.15' not in the model
# '3' not in the model

# %%
print(len(test_input)) # num_batches
print(len(test_input[0])) # input, label (vector), label (text)
print(test_input[0][0].shape) # batch shape
# Out:
# 200
# 3
# torch.Size([1500])

# %%
# test the best model (relu no softmax)
model_nn = torch.load('./nn.nosoftmax.best.model')
model_nn.eval()
with torch.no_grad():
    for data, target, text_label in test_input:
        output = model_nn(data)
        # for each taget embedding, see if the most similar word is the same with actual
        # if the actual is in top 5 of the most similar word with the predicted embedding
        # count correct + 1
        top5_most_similar = glove_model.most_similar_token(output, topn=5)
        print('current word: {}'.format(text_label))
        print('   top five prediction: {}'.format(top5_most_similar))
# Out:
# current word: forne
#    top five prediction: [('our', 0.8568243573257759), ('friends', 0.8440370482460278), ('family', 0.8414293473396705), ('there', 0.8398773558643973), ('other', 0.8312588289647292)]
# current word: forne
#    top five prediction: [('there', 0.8817443123554898), ('many', 0.8792584528454666), ('things', 0.8757930090643414), ('how', 0.86911960144686), ('any', 0.8688549018653574)]
# current word: ennoying
#    top five prediction: [('there', 0.9492946888835155), ('think', 0.9449170534802956), ('but', 0.9401724706773426), ("n't", 0.9376505046196539), ('it', 0.9327837944200056)]
# current word: sinccerly
#    top five prediction: [('first', 0.8447360751970565), ('other', 0.8408892264593248), ('about', 0.8395984650449209), ('any', 0.8379450984628121), ('thing', 0.8361936869863933)]
# current word: pressume
#    top five prediction: [('know', 0.9463690292789775), ('there', 0.9416180443622981), ("n't", 0.9381204236278791), ('but', 0.9356723554041914), ('how', 0.9292456471990407)]
# current word: fhing
#    top five prediction: [('that', 0.932265359027427), ('there', 0.9261284992113377), ('but', 0.9242957954648232), ('it', 0.9214125158069987), ('way', 0.9187008097652248)]
# current word: sathurday
#    top five prediction: [('sunday', 0.9164063101701265), ('friday', 0.9153929496031763), ('monday', 0.915131070734183), ('thursday', 0.9006651941381592), ('tomorrow', 0.8982820306876139)]
# current word: troubbles
#    top five prediction: [('which', 0.8795806220727402), ('there', 0.8769744234910198), ('that', 0.871744169182529), ('other', 0.8687348255625623), ('how', 0.8642312710175122)]
# current word: organying
#    top five prediction: [('where', 0.8661824523680579), ('the', 0.8640851907871397), ('this', 0.8595846232523924), ('our', 0.8557058885806238), ('way', 0.8557026249309693)]
# current word: concers
#    top five prediction: [('regarding', 0.7676190974756195), ('any', 0.7636997740021033), ('about', 0.7474690639858736), ('anyone', 0.7456943840842782), ('despite', 0.7454230468636144)]
# current word: caracterize
#    top five prediction: [('how', 0.9315272145812704), ('there', 0.9236145421148266), ('know', 0.9226802554380928), ("n't", 0.921701717992596), ('when', 0.9178334326505259)]
# current word: well-orginised
#    top five prediction: [('organized', 0.7272435642459938), ('established', 0.6675001081852246), ('encouraged', 0.6623435204700121), ('celebrated', 0.6579101153372064), ('accompanied', 0.6574050135380782)]
# current word: stily
#    top five prediction: [('the', 0.8467781778778399), ('it', 0.8457599521611623), ('that', 0.8408438027020655), ('how', 0.8393518100507106), ('other', 0.8383702422749959)]
# current word: recommand
#    top five prediction: [('you', 0.9320749551927593), ('know', 0.9312407846498596), ('think', 0.9294191866724231), ("'ll", 0.9278909842837801), ('have', 0.9236839540093714)]
# current word: appliaces
#    top five prediction: [('that', 0.8983530415013211), ('there', 0.8800937593337055), ('thing', 0.879860978587529), ('because', 0.8735205272750411), ('it', 0.8724327843762019)]
# current word: whed
#    top five prediction: [('know', 0.9523540280687434), ("n't", 0.9463822012298934), ('but', 0.9399202974404983), ('there', 0.9376315101127707), ('you', 0.9291222757740065)]
# current word: visitores
#    top five prediction: [('any', 0.8288675472782074), ('other', 0.8265725945314184), ('going', 0.8219079517972525), ('our', 0.8218868542406342), ('looking', 0.8214872343265437)]
# current word: intrestng
#    top five prediction: [('thing', 0.8785082938542164), ('there', 0.8775974619209181), ('but', 0.8687794695959725), ('very', 0.8676253256932034), ('really', 0.8661314729840803)]
# current word: promontion
#    top five prediction: [('way', 0.8726396753644052), ('when', 0.86770247871174), ('going', 0.8664636390517949), ('not', 0.8613307330321929), ('about', 0.8600920992188513)]
# current word: languagers
#    top five prediction: [('cultures', 0.7385601418068743), ('languages', 0.7333032995308282), ('cities', 0.7151216447114969), ('nations', 0.6956924212603542), ('companies', 0.6776978462087162)]
# current word: mentionned
#    top five prediction: [('think', 0.9187489097408552), ('told', 0.9183534999648076), ('did', 0.9129770139977879), ('should', 0.9110511684004484), ('said', 0.9051214614600512)]
# current word: writeing
#    top five prediction: [('write', 0.8564849743906744), ('reading', 0.8284279343239802), ('essay', 0.8143914428265324), ('book', 0.7822589955908892), ('read', 0.7637145296288248)]
# current word: atracite
#    top five prediction: [('there', 0.894955250469505), ('any', 0.879690711286869), ('yet', 0.8785759325116049), ('way', 0.8746529190498439), ('which', 0.8710597134706217)]
# current word: ?!
#    top five prediction: [('there', 0.910284213930474), ('how', 0.9090636775522599), ('not', 0.9079198654247946), ('that', 0.9056049901034829), ("n't", 0.9054647170187626)]
# current word: incomon
#    top five prediction: [('like', 0.8475219168915419), ('it', 0.8412388825202937), ("n't", 0.8406148439212002), ('but', 0.8377023963509084), ('think', 0.8356292758650596)]
# current word: concerntration
#    top five prediction: [('when', 0.881661759954702), ('thing', 0.8805338999896353), ('way', 0.877654312042553), ('have', 0.8772908857555294), ('where', 0.8758135974328182)]
# current word: opionions
#    top five prediction: [('information', 0.7829779345177459), ('suggestions', 0.7797828335545057), ('regarding', 0.7783748121268519), ('recommendations', 0.7541358679799024), ('questions', 0.7523095248191138)]
# current word: calulate
#    top five prediction: [('hence', 0.7234668133857469), ('difficult', 0.7206695771714179), ('easier', 0.7105483233397238), ('require', 0.7038143107544824), ('allow', 0.6978368236819568)]
# current word: combinient
#    top five prediction: [('comfortable', 0.8078035591708417), ('rather', 0.8073776515811952), ('difficult', 0.801320350729313), ('seems', 0.7996026717948609), ('interesting', 0.7959784913971297)]
# current word: helpul
#    top five prediction: [('provide', 0.8181315594914529), ('useful', 0.7988986121635441), ('given', 0.7891783841083777), ('helpful', 0.7795725204241214), ('certainly', 0.7753766872016503)]
# current word: appreicate
#    top five prediction: [('give', 0.8650760576353141), ('anyone', 0.8591680677826926), ('need', 0.853367611444316), ('could', 0.8481586881294297), ('if', 0.8457953689978148)]
# current word: interesed
#    top five prediction: [('trying', 0.8488132576131723), ('thinking', 0.8350970968333911), ('doing', 0.8317962650772266), ('then', 0.8218586601535465), ('something', 0.8192468227103086)]
# current word: groue
#    top five prediction: [("'ve", 0.9214257695373379), ('thought', 0.9211581166349759), ('did', 0.9200760709651806), ('went', 0.9200678039611513), ('have', 0.9186346618321349)]
# current word: coluor
#    top five prediction: [('wearing', 0.8615155371057732), ('pants', 0.830446565399509), ('clothes', 0.8241612960560986), ('shoes', 0.8162204524577755), ('shirt', 0.8077788047490495)]
# current word: paht
#    top five prediction: [('there', 0.9060334145059652), ('but', 0.9007549478275301), ('way', 0.900360696555562), ('that', 0.8952047313467567), ('every', 0.8794143439478083)]
# current word: dungeen
#    top five prediction: [('experience', 0.7558909033471923), ('which', 0.7387327182456364), ('guide', 0.7299712143105742), ('first', 0.712829268878257), ('our', 0.710991907116548)]
# current word: disadvatage
#    top five prediction: [('thing', 0.8430919262686062), ('which', 0.8346450727438826), ('change', 0.8296596487866079), ('however', 0.8253820700527681), ('there', 0.8235881159052881)]
# current word: conclusuon
#    top five prediction: [('where', 0.8661823386093794), ('the', 0.8640850780317748), ('this', 0.8595845132756964), ('our', 0.8557057779791098), ('way', 0.8557025124944516)]
# current word: stricht
#    top five prediction: [('enough', 0.8344847534938686), ('pretty', 0.8324514898860982), ('nice', 0.831111041138281), ('interesting', 0.8298471093572077), ('more', 0.823669804247484)]
# current word: beheviour
#    top five prediction: [('one', 0.8618999164412133), ('there', 0.8611439452539482), ('like', 0.8534125031014812), ('what', 0.8479348025640143), ('that', 0.8464969757384262)]
# current word: strickt
#    top five prediction: [('way', 0.8818041899294535), ('it', 0.8602695763762587), ('this', 0.8596601978402604), ('really', 0.8567357201046754), ('but', 0.852716195163017)]
# current word: fesival
#    top five prediction: [('expo', 0.7865919346107768), ('fest', 0.7774885518620084), ('showcase', 0.7601863731697974), ('event', 0.75012738717278), ('tour', 0.7452026108773686)]
# current word: detailes
#    top five prediction: [('people', 0.8790677061991875), ('things', 0.8763441092536352), ('many', 0.8746198773268924), ('any', 0.8539775093701334), ('there', 0.8453859817760887)]
# current word: pursuading
#    top five prediction: [('concerning', 0.777562884990666), ('aware', 0.7609631620178388), ('considering', 0.7587539566341045), ('consider', 0.7512486055086007), ('concerned', 0.751137153711064)]
# current word: organiced
#    top five prediction: [('have', 0.940886903574838), ('there', 0.9395822731280595), ('know', 0.939235694211777), ('think', 0.9367113009408339), ('that', 0.9317741311078582)]
# current word: 21
#    top five prediction: [('days', 0.8951540644663668), ('there', 0.8917368451891737), ('this', 0.8902383846434773), ('today', 0.8886763163721033), ('way', 0.8819738404979273)]
# current word: organiced
#    top five prediction: [('organized', 0.7020002262513458), ('encouraged', 0.6732157016991105), ('established', 0.6559123958687088), ('pleased', 0.6445183620473021), ('celebrated', 0.6341193571232905)]
# current word: concets
#    top five prediction: [('library', 0.7772894515849936), ('conference', 0.77338704282374), ('theatre', 0.7710928089359992), ('london', 0.7677211915076215), ('east', 0.7654738533006539)]
# current word: carrear
#    top five prediction: [('way', 0.8698814044012234), ('where', 0.8668852150634877), ('this', 0.8661321264115792), ('the', 0.864307326979133), ('out', 0.8638474600162491)]
# current word: foregive
#    top five prediction: [('think', 0.9481601995534246), ('know', 0.9477303500757115), ('need', 0.9367449085782127), ('if', 0.9335153853658061), ('have', 0.9295265664674458)]
# current word: schoes
#    top five prediction: [('our', 0.8815697986134896), ('other', 0.8727713014215764), ('where', 0.8657387823095498), ('way', 0.8584768962832825), ('life', 0.8580096392375911)]
# current word: kownlegth
#    top five prediction: [('there', 0.8941077772110911), ('our', 0.8787852604500815), ('way', 0.8726185040161489), ('where', 0.8710582278098142), ('they', 0.8699144745808672)]
# current word: intesting
#    top five prediction: [('other', 0.8664295045944873), ('more', 0.8648651807009183), ('there', 0.862235959711688), ('many', 0.8503512773387268), ('find', 0.8468449843221829)]
# current word: salaly
#    top five prediction: [('which', 0.8741894424713736), ('but', 0.8741673434167097), ('that', 0.8738438298361964), ('thing', 0.8677672410719449), ('because', 0.8666866433354088)]
# current word: congratualate
#    top five prediction: [('give', 0.8726562167888947), ('hope', 0.8631266792628193), ('if', 0.8599797547445046), ('anyone', 0.8464477302333779), ('see', 0.8456228924255014)]
# current word: festivel
#    top five prediction: [('there', 0.8391647320885861), ('our', 0.8328204113449041), ('which', 0.8230208289827238), ('where', 0.8174582059042), ('first', 0.8158922981277738)]
# current word: vareiety
#    top five prediction: [('outdoor', 0.7187795431316532), ('features', 0.6937416167128696), ('collection', 0.693371863433458), ('production', 0.6907439689672792), ('quality', 0.6781304180222267)]
# current word: claryfy
#    top five prediction: [('answers', 0.7883115589365219), ('asked', 0.7694993544046486), ('tell', 0.768501557374953), ('asking', 0.7653618569688423), ('does', 0.7572265311352787)]
# current word: portrate
#    top five prediction: [('way', 0.8698813412827296), ('where', 0.8668851530563084), ('this', 0.8661320649816674), ('the', 0.8643072657728055), ('out', 0.8638473993221257)]
# current word: contries
#    top five prediction: [('cities', 0.8526596483688178), ('states', 0.7664106360049032), ('europe', 0.7586700057663213), ('nations', 0.737364666091252), ('americans', 0.7336719916213903)]
# current word: nationallites
#    top five prediction: [('including', 0.7549491921649507), ('provide', 0.743522108219307), ('different', 0.7417178409148685), ('websites', 0.7404535253982174), ('any', 0.7345324617416114)]
# current word: teeenage
#    top five prediction: [('going', 0.8620156547290576), ('days', 0.8571064079794974), ('next', 0.8562988815436282), ('here', 0.8527211718355586), ('day', 0.8523261712840035)]
# current word: appoitments
#    top five prediction: [('any', 0.815114696752846), ('details', 0.8047366892824648), ('other', 0.7955301336684384), ('many', 0.7942688482160133), ('people', 0.7909221760543972)]
# current word: exbitions
#    top five prediction: [('design', 0.7885911463566997), ('which', 0.7633183619987702), ('interesting', 0.7546603997027316), ('research', 0.7511529488780306), ('based', 0.7487822835577667)]
# current word: excenent
#    top five prediction: [('important', 0.8392772231647118), ('useful', 0.7936142106884191), ('very', 0.7905446487164389), ('excellent', 0.7865317979864388), ('however', 0.7835431497555739)]
# current word: halled
#    top five prediction: [('few', 0.7959398274238322), ('going', 0.7760513312071733), ('lot', 0.7722861405482224), ('could', 0.7681324536081444), ('seeing', 0.7677990283103779)]
# current word: diciplined
#    top five prediction: [('necessary', 0.7925065202854836), ('however', 0.7901339935828741), ('difficult', 0.7893853955207867), ('example', 0.7806762203757167), ('ways', 0.7609934283543688)]
# current word: commitent
#    top five prediction: [('either', 0.8143895243120072), ('work', 0.8137920648152208), ('instead', 0.809109834451435), ('however', 0.8087515475719045), ('there', 0.805221284389596)]
# current word: 20.15
#    top five prediction: [('then', 0.8558190991446892), ('last', 0.839814519622593), ('way', 0.8304032507743851), ('there', 0.8291489664190632), ('now', 0.8281199203969475)]
# current word: wersting
#    top five prediction: [('only', 0.9191425632907771), ('one', 0.9150670987942868), ('when', 0.9142332675347852), ('that', 0.913206013751632), ('but', 0.9121778696739871)]
# current word: developes
#    top five prediction: [('spent', 0.8883160321319044), ('having', 0.865187043663795), ('almost', 0.8529899799768664), ('probably', 0.846812250071891), ('instead', 0.8403285542479897)]
# current word: impruvement
#    top five prediction: [('exhibition', 0.7357021798103589), ('arts', 0.718324781988275), ('institute', 0.7154706719949351), ('art', 0.7061693524743196), ('museums', 0.7032108090301377)]
# current word: smailing
#    top five prediction: [('think', 0.9266115464997381), ('how', 0.9164930307018176), ('know', 0.9113000963858982), ('that', 0.9097555386567869), ('when', 0.9079651705093004)]
# current word: 19.30
#    top five prediction: [('any', 0.8521656867720255), ('our', 0.8477544839997521), ('which', 0.8453916251731238), ('have', 0.842068812371644), ('many', 0.8403494891121036)]
# current word: 19.30
#    top five prediction: [('there', 0.9026019084210105), ('this', 0.892001057246865), ('today', 0.8893647866104889), ('next', 0.8872676874517902), ('out', 0.8845742423794809)]
# current word: 10
#    top five prediction: [('spent', 0.8834272808131043), ('spending', 0.8610938111277453), ('worth', 0.7900546745032058), ('pay', 0.7853125445017117), ('paid', 0.7843198161082103)]
# current word: advertisiment
#    top five prediction: [('the', 0.8447351720519091), ('our', 0.8366436391477833), ('next', 0.8339476629371493), ('where', 0.8312375381794337), ('going', 0.8309190862767406)]
# current word: publised
#    top five prediction: [('have', 0.940886903574838), ('there', 0.9395822731280595), ('know', 0.939235694211777), ('think', 0.9367113009408339), ('that', 0.9317741311078582)]
# current word: unpleased
#    top five prediction: [('think', 0.9243030223875043), ('know', 0.921771164924729), ('there', 0.9205659135638291), ("n't", 0.9158292641582068), ('really', 0.9126222339463848)]
# current word: heaed
#    top five prediction: [('there', 0.9111157757976611), ('when', 0.9101123465138605), ('think', 0.9096637576436328), ('could', 0.9062731234968086), ('did', 0.9058664719875611)]
# current word: safty-money
#    top five prediction: [('and', 0.8389129365416844), ("'s", 0.828971110327707), ('one', 0.819997912993937), ('from', 0.8190943444212151), ('show', 0.815141143417217)]
# current word: schoked
#    top five prediction: [('they', 0.8566197665783191), ("'ve", 0.8518324015136602), ('however', 0.8510812461923704), ('because', 0.8505315318063624), ('many', 0.8457698089899756)]
# current word: mr/mss
#    top five prediction: [('mr.', 0.9332634928018948), ('ms.', 0.8936527717639708), ('mrs', 0.8919668644172073), ('mr', 0.8309164534707854), ('aka', 0.7738372669234178)]
# current word: 20:15
#    top five prediction: [('there', 0.9026019084210105), ('this', 0.892001057246865), ('today', 0.8893647866104889), ('next', 0.8872676874517902), ('out', 0.8845742423794809)]
# current word: 19:30
#    top five prediction: [('there', 0.9026017888067287), ('this', 0.8920009409395652), ('today', 0.8893646707760403), ('next', 0.8872675720429942), ('out', 0.8845741267146489)]
# current word: techology
#    top five prediction: [('tech', 0.8512587995254516), ('innovation', 0.8005316780337546), ('systems', 0.796521559531711), ('development', 0.7856569413529388), ('enterprise', 0.7715178283049704)]
# current word: centure
#    top five prediction: [('there', 0.8929675510680202), ('the', 0.890793535765776), ('first', 0.8881654907946891), ('next', 0.8821681822112243), ('out', 0.8756859792658557)]
# current word: advertistment
#    top five prediction: [('next', 0.8513572971219934), ('first', 0.8407797636065281), ('our', 0.8347112689734397), ('this', 0.8165911102143054), ('year', 0.8145247057500979)]
# current word: advertissement
#    top five prediction: [('first', 0.8447360751970565), ('other', 0.8408892264593248), ('about', 0.8395984650449209), ('any', 0.8379450984628121), ('thing', 0.8361936869863933)]
# current word: gratfull
#    top five prediction: [('need', 0.9360955992869566), ('have', 0.9261955838719014), ('get', 0.9212396800141759), ('you', 0.9194231626236404), ('know', 0.9153658615499106)]
# current word: charakters
#    top five prediction: [('days', 0.8258393978397108), ('since', 0.8162027729626933), ('yet', 0.8095858971960054), ('which', 0.8045428495842567), ('times', 0.8030093768699855)]
# current word: sourranding
#    top five prediction: [('that', 0.9189944485234739), ('only', 0.9151058251492935), ('how', 0.9116859048842215), ('other', 0.9097452228341222), ('because', 0.9090638496509855)]
# current word: disadvantatges
#    top five prediction: [('thing', 0.8785082938542164), ('there', 0.8775974619209181), ('but', 0.8687794695959725), ('very', 0.8676253256932034), ('really', 0.8661314729840803)]
# current word: advantatges
#    top five prediction: [('next', 0.8842223028685836), ('until', 0.882530502481009), ('today', 0.8738974555922663), ('before', 0.872797950571225), ('last', 0.87246946656647)]
# current word: anwered
#    top five prediction: [('have', 0.9160617866608269), ('did', 0.9157087513514461), ('that', 0.9153723131348109), ('think', 0.9149024411368867), ('thought', 0.9142880951959008)]
# current word: apologaising
#    top five prediction: [('if', 0.9004595625824621), ('take', 0.8964532132861304), ("'ll", 0.895358133793433), ('should', 0.8939604173702702), ("n't", 0.8928974959017688)]
# current word: unavilable
#    top five prediction: [('however', 0.8132299263605653), ('yet', 0.7996802165906036), ('based', 0.7913086693331749), ('offers', 0.7811318812347413), ('any', 0.7784016108572782)]
# current word: adition
#    top five prediction: [('this', 0.8694709190471683), ('there', 0.8639480000975474), ('next', 0.8630550773542923), ('our', 0.8616942359625308), ('the', 0.8584866338052701)]
# current word: simplier
#    top five prediction: [('museum', 0.7303336841849377), ('living', 0.7212187433438804), ('great', 0.701099894163389), ('way', 0.6948770779437493), ('built', 0.6903684209220601)]
# current word: learm
#    top five prediction: [('thought', 0.927682821010463), ('just', 0.9205651959191252), ('that', 0.9175414982379129), ('think', 0.916326789123459), ('told', 0.9090952222141534)]
# current word: embarased
#    top five prediction: [('enough', 0.8753125138765585), ('seems', 0.8630219807778431), ('especially', 0.8618196832728132), ('rather', 0.8577078700428805), ('lot', 0.8567654399441513)]
# current word: 20.15
#    top five prediction: [('there', 0.9026017888067287), ('this', 0.8920009409395652), ('today', 0.8893646707760403), ('next', 0.8872675720429942), ('out', 0.8845741267146489)]
# current word: beginig
#    top five prediction: [('the', 0.7917070870579258), ('museum', 0.7884734213279816), ('place', 0.7746554029107422), ('end', 0.7743593129062074), ('world', 0.773071178296151)]
# current word: complaines
#    top five prediction: [('our', 0.8622892558828954), ('friends', 0.8514090699741417), ('other', 0.851136511521136), ('where', 0.8442430656183277), ('work', 0.8432175680469294)]
# current word: surranding
#    top five prediction: [('showed', 0.7169800515937478), ('claimed', 0.7052993703082169), ('himself', 0.6971058438437084), ('takes', 0.689506322762307), ('clearly', 0.6827458280434842)]
# current word: recompansate
#    top five prediction: [('think', 0.9431742960475038), ('should', 0.9301803655476858), ('know', 0.9279791298022857), ('have', 0.9275983966107828), ('there', 0.9274344862061014)]
# current word: healf
#    top five prediction: [('create', 0.7877644701440493), ('creating', 0.7719884636743567), ('value', 0.7622472678142667), ('provide', 0.7610127823464286), ('experiences', 0.7585096397782986)]
# current word: 19:30
#    top five prediction: [('there', 0.9026019084210105), ('this', 0.892001057246865), ('today', 0.8893647866104889), ('next', 0.8872676874517902), ('out', 0.8845742423794809)]
# current word: camirez
#    top five prediction: [('name', 0.8028092935943196), ('sister', 0.7901740424976254), ('mother', 0.7846439742054845), ('friends', 0.7798526346400909), ('father', 0.7795610471784788)]
# current word: compleints
#    top five prediction: [('many', 0.8805676369657061), ('any', 0.8775942556162213), ('people', 0.8727707334082465), ('there', 0.8623516707933992), ('them', 0.8468111309218883)]
# current word: 19.30
#    top five prediction: [('there', 0.9026017888067287), ('this', 0.8920009409395652), ('today', 0.8893646707760403), ('next', 0.8872675720429942), ('out', 0.8845741267146489)]
# current word: 40
#    top five prediction: [('weeks', 0.8781640311278027), ('hours', 0.8737503471865152), ('years', 0.8671376847538393), ('months', 0.8610420917966776), ('days', 0.8567377671926409)]
# current word: demostrated
#    top five prediction: [('otherwise', 0.8334576505743008), ('although', 0.8283235330445632), ('seems', 0.8235749775993471), ('perhaps', 0.8218346714179721), ('rather', 0.820600505714764)]
# current word: complein
#    top five prediction: [('see', 0.9090710229670391), ("n't", 0.9071037494974794), ("'ll", 0.9008143765488593), ('going', 0.8973455203267963), ('let', 0.8967435971387531)]
# current word: explein
#    top five prediction: [('have', 0.9118816102386104), ('think', 0.9070353159470135), ('they', 0.9024918932321268), ("n't", 0.8987104273902476), ('could', 0.898424335597251)]
# current word: phisically
#    top five prediction: [('two', 0.920101207359809), ('there', 0.8917855445993109), ('only', 0.8904077618034189), ('three', 0.8818523616832812), ('first', 0.8753009261295619)]
# current word: 19:30
#    top five prediction: [('there', 0.9026017888067287), ('this', 0.8920009409395652), ('today', 0.8893646707760403), ('next', 0.8872675720429942), ('out', 0.8845741267146489)]
# current word: 20.15
#    top five prediction: [('there', 0.9026017888067287), ('this', 0.8920009409395652), ('today', 0.8893646707760403), ('next', 0.8872675720429942), ('out', 0.8845741267146489)]
# current word: 19:30
#    top five prediction: [('have', 0.903254063720474), ('this', 0.8993344982698547), ('way', 0.8973961987154199), ('yet', 0.8970235434202053), ('going', 0.8948982932061011)]
# current word: avaivable
#    top five prediction: [('are', 0.9537309006086416), ('they', 0.922878506676045), ('there', 0.8899779666883337), ('have', 0.8892000528421364), ('both', 0.8828703068199999)]
# current word: opertunity
#    top five prediction: [('opportunity', 0.8049976810059172), ('another', 0.7924090315310287), ('yet', 0.7905617628411895), ('first', 0.77761937760112), ('any', 0.774580141365171)]
# current word: opertunity
#    top five prediction: [('any', 0.8412700775508254), ('place', 0.83145145337982), ('our', 0.8234923224563881), ('next', 0.8195667085983005), ('work', 0.8193896377968867)]
# current word: disatvantage
#    top five prediction: [('approach', 0.7639036490644935), ('business', 0.7520717923214353), ('value', 0.742182261607998), ('client', 0.7348655039556078), ('important', 0.7338958279010259)]
